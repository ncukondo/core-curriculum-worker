# %%
#!/usr/bin/env python
# coding: utf-8

import csv
import pandas as pd


r4_l1=pd.read_csv("./raw/sheets/R4コアカリ提出用/第1層.csv")
r4_l2=pd.read_csv("./raw/sheets/R4コアカリ提出用/第2層.csv")

columns=["第2層","第3層","第4層","メモ","H28対応項目"]
r4_l234 = pd.DataFrame(data=[],columns=columns)
tabs=r4_l1["タブ名"]
for tab in tabs:
    r4_l34_unit=pd.read_csv(f"./raw/sheets/R4コアカリ提出用/{tab}.csv")
    r4_l234=pd.concat([r4_l234,r4_l34_unit.loc[:,columns]])

r4_l12=pd.merge(r4_l1,r4_l2,how="outer").rename(columns={"メモ":"第2層メモ"})
r4_full=pd.merge(r4_l12,r4_l234,how="outer")
r4_full=r4_full.dropna(subset=["第1層","第2層","第3層","第4層"])

r4_no_disc=r4_full.loc[:,["第1層","第2層","第3層","第4層"]]

r4_full.to_csv("./dist/r4_full.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_full.csv")
r4_no_disc.to_csv("./dist/r4_no_disc.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_no_dics.csv")

r4_full
# Out:
# output... r4_full.csv
# output... r4_no_dics.csv
#     タブ名 第1層イニシャル             第1層  \
# 0    プロ       PR     プロフェッショナリズム
# 1    プロ       PR     プロフェッショナリズム
# 2    プロ       PR     プロフェッショナリズム
# 3    プロ       PR     プロフェッショナリズム
# 4    プロ       PR     プロフェッショナリズム
# ..   ..      ...             ...
# 816  社会       SO  社会における医療の役割の理解
# 817  社会       SO  社会における医療の役割の理解
# 818  社会       SO  社会における医療の役割の理解
# 819  社会       SO  社会における医療の役割の理解
# 820  社会       SO  社会における医療の役割の理解
#
#                                                  第1層説明  \
# 0    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 1    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 2    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 3    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 4    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# ..                                                 ...
# 816  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 817  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 818  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 819  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 820  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
#
#                                                 編集用シート             第2層  \
# 0    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 1    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 2    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 3    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 4    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# ..                                                 ...             ...
# 816  https://docs.google.com/spreadsheets/d/10J6QQh...   国内外の視点から捉える医療
# 817  https://docs.google.com/spreadsheets/d/10J6QQh...   国内外の視点から捉える医療
# 818  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 819  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 820  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
#
#                                                  第2層説明 第2層メモ  \
# 0               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 1               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 2               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 3               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 4               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# ..                                                 ...   ...
# 816             国内、及び、国際社会の中で規定される医療の役割と医療体制について概説できる。   NaN
# 817             国内、及び、国際社会の中で規定される医療の役割と医療体制について概説できる。   NaN
# 818  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
# 819  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
# 820  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
#
#                   第3層                                                第4層  \
# 0                 誠実さ                      どのように行動すれば患者や社会に対して誠実に振る舞えるか？
# 1                 誠実さ                社会から信頼される専門職集団であるためにはどのように行動すればよいか？
# 2                 誠実さ                             どのように行動すれば守秘義務を遵守できるか？
# 3                  省察                         どのようにすれば自分自身の限界を適切に認識できるか？
# 4                  省察             他者からのフィードバックを受け入れられるにはどのような心持ちでいればよいか？
# ..                ...                                                ...
# 816  グルーバルヘルスの役割や医療体制  UHC(Universal health coverage)とは何かを概説し、各国の医療制度...
# 817  グルーバルヘルスの役割や医療体制                              保健関連SDGや国際援助組織を概説できる。
# 818       社会科学と医療との関係        社会科学（主に医療人類学や医療社会学）の基本的な視点・方法・理論を用いることができる。
# 819       社会科学と医療との関係   医療に関する諸事象をシステム論の観点から社会の諸制度との関わりのなかで捉え、構造的に説明できる。
# 820       社会科学と医療との関係  人びとの生活の場において健康・病気・死とそれらをめぐる医療がどのようにとらえられているかを探...
#
#                                                     メモ  \
# 0    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 1    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 2    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 3    プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムでは「医...
# 4    新設,プロフェッショナリズムという概念は多義的であるが、医学教育モデル・コア・カリキュラムで...
# ..                                                 ...
# 816                                                NaN
# 817                                                NaN
# 818                             部会からの提案を一部修正した案を採用（春田）
# 819                             部会からの提案を一部修正した案を採用（春田）
# 820                             部会からの提案を一部修正した案を採用（春田）
#
#                          H28対応項目
# 0                  A-01-03-na-01
# 1                  A-01-03-na-01
# 2                  A-04-02-na-07
# 3                  A-01-03-na-04
# 4                            NaN
# ..                           ...
# 816  B-01-09-na-01,B-01-09-na-01
# 817  B-01-09-na-01,B-01-09-na-01
# 818               B-04-01-na-01,
# 819               B-04-01-na-08,
# 820               B-04-01-na-02,
#
# [821 rows x 12 columns]

# %%
import csv
import pandas as pd

r4_l1_draft=pd.read_csv("./raw/sheets/R4コアカリ提出用/第1層.csv")
r4_l2_draft=pd.read_csv("./raw/sheets/R4コアカリ提出用/第2層.csv")

columns=["第2層","第3層","第4層","メモ","UID","H28対応項目"]
r4_l234_draft = pd.DataFrame(data=[],columns=columns)
tabs=r4_l1_draft["タブ名"]
for tab in tabs:
    r4_l34_unit=pd.read_csv(f"./raw/sheets/{tab}編集用/第2から4層.csv")
    r4_l234_draft=pd.concat([r4_l234_draft,r4_l34_unit.loc[:,columns]])

r4_l12_draft=pd.merge(r4_l1_draft,r4_l2_draft,how="outer").rename(columns={"メモ":"第2層メモ"})
r4_full_draft=pd.merge(r4_l12_draft,r4_l234_draft,how="outer")
r4_full_draft=r4_full_draft.dropna(subset=["第1層","第2層","第3層","第4層"])
r4_full_draft.to_csv("./dist/r4_draft.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_draft.csv")

r4_full_draft
# Out:
# output... r4_draft.csv
#     タブ名 第1層イニシャル             第1層  \
# 0    プロ       PR     プロフェッショナリズム
# 1    プロ       PR     プロフェッショナリズム
# 2    プロ       PR     プロフェッショナリズム
# 3    プロ       PR     プロフェッショナリズム
# 4    プロ       PR     プロフェッショナリズム
# ..   ..      ...             ...
# 847  社会       SO  社会における医療の役割の理解
# 848  社会       SO  社会における医療の役割の理解
# 849  社会       SO  社会における医療の役割の理解
# 850  社会       SO  社会における医療の役割の理解
# 851  社会       SO  社会における医療の役割の理解
#
#                                                  第1層説明  \
# 0    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 1    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 2    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 3    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 4    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# ..                                                 ...
# 847  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 848  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 849  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 850  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
# 851  医療は社会の一部であるという認識を持ち、経済的な観点・地域性の視点・国際的な視野も持ちながら...
#
#                                                 編集用シート             第2層  \
# 0    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 1    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 2    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 3    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# 4    https://docs.google.com/spreadsheets/d/1So2CGT...              信頼
# ..                                                 ...             ...
# 847  https://docs.google.com/spreadsheets/d/10J6QQh...   国内外の視点から捉える医療
# 848  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 849  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 850  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
# 851  https://docs.google.com/spreadsheets/d/10J6QQh...  社会科学の視点から捉える医療
#
#                                                  第2層説明 第2層メモ  \
# 0               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 1               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 2               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 3               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# 4               誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす   NaN
# ..                                                 ...   ...
# 847             国内、及び、国際社会の中で規定される医療の役割と医療体制について概説できる。   NaN
# 848  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
# 849  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
# 850  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
# 851  医学的・文化的・社会的文脈のなかで生成される健康観や人びとの言動・関係性を理解し、社会科学 ...   NaN
#
#                   第3層                                                第4層  \
# 0                 誠実さ            患者や社会に対して誠実であるとはどういうことか考え適切に行動することができる。
# 1                 誠実さ   社会から信頼される専門職集団の一員であるためにはどうすれば良いか考え適切に行動することができる。
# 2                 誠実さ                          削除：どのように行動すれば守秘義務を遵守できるか？
# 3                  省察                               自分自身の限界を適切に認識し行動できる。
# 4                  省察                       他者からのフィードバックを適切に受け入れることができる。
# ..                ...                                                ...
# 847  グルーバルヘルスの役割や医療体制           保健関連の国連開発目標や国際機関・国際協力に関わる組織・団体について概説できる。
# 848       社会科学と医療との関係     日常生活や外来診療・在宅療養・入院・施設入所等において、健康・病気・死の捉え方を探索できる。
# 849       社会科学と医療との関係    時代の流れ、社会の状況や諸制度との関わりのなかで医療に関する諸事象を捉え、構造的に説明できる。
# 850       社会科学と医療との関係  削除：人びとの生活の場において健康・病気・死とそれらをめぐる医療がどのようにとらえられている...
# 851       社会科学と医療との関係          個や集団に及ぼす文化・慣習による影響（コミュニケーションのあり方等）を説明できる。
#
#                                                     メモ      UID  \
# 0                                                  NaN  JkxiJUs
# 1                                                  NaN  JkxiJUw
# 2    「情報」にあれば「情報」で取り扱っていただく・なければプロフェッショナリズムで・下記「患者安...  JkxiJU0
# 3                                                  NaN  JkxiJU4
# 4                                                  NaN  JkxiJU8
# ..                                                 ...      ...
# 847                                                NaN  JkxoNws
# 848                             部会からの提案を一部修正した案を採用（春田）  JkxoNxQ
# 849                             部会からの提案を一部修正した案を採用（春田）  JkxoNxU
# 850                             部会からの提案を一部修正した案を採用（春田）  JkxoNw4
# 851                                                 修正  JkxoNxc
#
#                          H28対応項目
# 0                  A-01-03-na-01
# 1                  A-01-03-na-01
# 2                  A-04-02-na-07
# 3                  A-01-03-na-04
# 4                            NaN
# ..                           ...
# 847  B-01-09-na-01,B-01-09-na-01
# 848               B-04-01-na-01,
# 849               B-04-01-na-08,
# 850               B-04-01-na-02,
# 851  C-05-07-na-07,C-05-07-na-08
#
# [846 rows x 13 columns]

# %%
import csv
import pandas as pd

r4_l1=pd.read_csv("./raw/sheets/R4コアカリ提出用/第1層.csv")
r4_l2=pd.read_csv("./raw/sheets/R4コアカリ提出用/第2層.csv")

columns=["第2層","第3層","UID","第4層","メモ","H28対応項目"]
r4_l234_0131 = pd.DataFrame(data=[],columns=columns)
l1=r4_l1["第1層"]
for l1_name in l1:
    r4_l34_unit=pd.read_csv(f"./raw/sheets/{l1_name}_0131版_査読/第2から4層.csv")
    r4_l234_0131=pd.concat([r4_l234_0131,r4_l34_unit])

r4_l12_0131=pd.merge(r4_l1,r4_l2,how="outer").rename(columns={"メモ":"第2層メモ"})
r4_0131=pd.merge(r4_l12_0131,r4_l234_0131,how="outer")
r4_0131=r4_0131.fillna("")
r4_0131.to_csv("./dist/r4_0131.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_0131.csv")

r4_0131_review = r4_0131.loc[:,["第1層イニシャル","UID","査読への返答","A","B","C","D","E","F","G","H","I"]]
r4_0131_review.to_csv("./dist/r4_0131_review.csv",encoding="utf_8_sig",quoting=csv.QUOTE_NONNUMERIC,index=False)
print("output... r4_0131_review.csv")


r4_0131
# Out:
# output... r4_0131.csv
# output... r4_0131_review.csv
#     タブ名 第1層イニシャル          第1層  \
# 0    プロ       PR  プロフェッショナリズム
# 1    プロ       PR  プロフェッショナリズム
# 2    プロ       PR  プロフェッショナリズム
# 3    プロ       PR  プロフェッショナリズム
# 4    プロ       PR  プロフェッショナリズム
# ..   ..      ...          ...
# 821
# 822
# 823
# 824
# 825
#
#                                                  第1層説明  \
# 0    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 1    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 2    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 3    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# 4    人の命に深く関わり健康を守るという医師の職責を十分に自覚し、多様性・人間性を尊重し、利他的な...
# ..                                                 ...
# 821
# 822
# 823
# 824
# 825
#
#                                                 編集用シート 第2層  \
# 0    https://docs.google.com/spreadsheets/d/1So2CGT...  信頼
# 1    https://docs.google.com/spreadsheets/d/1So2CGT...  信頼
# 2    https://docs.google.com/spreadsheets/d/1So2CGT...  信頼
# 3    https://docs.google.com/spreadsheets/d/1So2CGT...  信頼
# 4    https://docs.google.com/spreadsheets/d/1So2CGT...  信頼
# ..                                                 ...  ..
# 821
# 822
# 823
# 824
# 825
#
#                                       第2層説明 第2層メモ  第3層      UID  ...  \
# 0    誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす        誠実さ  JkxiJUs  ...
# 1    誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす        誠実さ  JkxiJUw  ...
# 2    誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす        誠実さ  JkxiJU0  ...
# 3    誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす         省察  JkxiJU4  ...
# 4    誠実に振る舞い、自ら省察し、患者の自律性を尊重するとともに、説明責任を果たす         省察  JkxiJU8  ...
# ..                                      ...   ...  ...      ...  ...
# 821                                                     JkxpswU  ...
# 822                                                     Jkxnuc0  ...
# 823                                                     Jkxp2Ik  ...
# 824                                                     JkxoNw8  ...
# 825                                                     JkxoNxA  ...
#
#                                                      A B   \
# 0    問いは斬新だが、到達すべき目標としては学修者にわかりにくく、評価も行いにくい（以下同文でこれ...
# 1    ・・・集団であることは、学修者の目標になるでしょうか。\n社会から信頼される専門職の一員であ...
# 2    守秘は情報で扱われると思います\n大切なことなので、ここで扱うことはよいと思いますが、情報と...
# 3          自身の限界を認識する習慣を身につけ、医師になるものとしての行動に結びつけることができる
# 4              他者からのフィードバックを受け入れる方法を持ち、受け入れる態度を身につけている
# ..                                                 ... ..
# 821
# 822
# 823
# 824
# 825
#
#                                                      C D   \
# 0
# 1    「信頼される専門職集団の一員であるためにはどのように行動すればよいか？」Community ...
# 2    「何が守秘義務の遵守を妨げるか？」望ましい態度としての表現でなくてもよいなら、こちらの問いの...
# 3    総合と技能で扱われている省察との関連を考えると、限界だけではなく、自分自身の特性、強みと弱み...
# 4    考えるのが難しい問いだと思いました。「何が他者からのフィードバックを受け入れることの障壁にな...
# ..                                                 ... ..
# 821
# 822
# 823
# 824
# 825
#
#                                                      E  \
# 0                           最も教育効果が小さい資質であり、漠とした問なので割愛
# 1
# 2
# 3
# 4    心持ちを変えるのは困難。むしろフィードバックの仕方を工夫した方が実効性がある。∴省察の元では...
# ..                                                 ...
# 821
# 822
# 823
# 824
# 825
#
#                                                      F G   \
# 0    表現についてですが、振る舞う　は、医師・医療ではなじまない気がしました。本心は　違う　という...
# 1
# 2
# 3
# 4
# ..                                                 ... ..
# 821
# 822
# 823
# 824
# 825
#
#                                                      H I  情報チーム
# 0
# 1
# 2         守秘義務についてはコミュニケーションの6でもでてきます。どちらかに統一すべきでしょうか？
# 3    自分自身の限界を受け止めることと他者のフィードバックを受け入れることは近いのではないかと感じ...
# 4
# ..                                                 ... ..   ...
# 821
# 822
# 823
# 824
# 825
#
# [826 rows x 25 columns]
