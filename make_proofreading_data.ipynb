# %%
import gspread
import pandas as pd
from lib.google_spread import get_sheetapp

r4_l1=pd.read_csv("./raw/gsheets/R4コアカリ提出用/第1層.csv")
'''
sheet_info=pd.DataFrame([],columns=["第1層","id","title"])
for l1_name in r4_l1["第1層"]:
    title=f'{l1_name}_0131版_査読'
    sheet=get_sheetapp().copy("1JzCRw2LR4IP__JrEgmUwnN0REuy66A5B4xo7KImFkmc",title=title,copy_permissions=True, folder_id="1NrjWTGweLNoUU1n-EH9yhIU5ZBUHOLs1")
    sheet_info=pd.concat([sheet_info,pd.DataFrame([[l1_name,sheet.id,sheet.title]],columns=["第1層","id","title"])])

sheet_info.to_csv("./dist/proof_reading_sheets2022_01_31.csv",encoding="utf_8_sig")
'''
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Input In [20], in <module>
#       8 for l1_name in r4_l1["第1層"]:
#       9     title=f'{l1_name}_0131版_査読'
# ---> 10     sheet=get_sheetapp().copy("1JzCRw2LR4IP__JrEgmUwnN0REuy66A5B4xo7KImFkmc",title=title,copy_permissions=True, folder_id="1NrjWTGweLNoUU1n-EH9yhIU5ZBUHOLs1")
#      11     sheet_info=pd.concat([sheet_info,pd.DataFrame([[l1_name,sheet.id,sheet.title]],columns=["第1層","id","title"])])
#      13 sheet_info.to_csv("./dist/proof_reading_sheets2022_01_31.csv",encoding="utf_8_sig")
#
# File /opt/conda/lib/python3.9/site-packages/gspread/client.py:245, in Client.copy(self, file_id, title, copy_permissions, folder_id)
#     242     payload["parents"] = [{"id": folder_id}]
#     244 params = {"supportsAllDrives": True}
# --> 245 r = self.request("post", url, json=payload, params=params)
# ...

# %%
sheet_info=pd.read_csv("./dist/proof_reading_sheets2022_01_31.csv")
sheet_info=pd.merge(sheet_info,r4_l1)
sheet_info

sheet=get_sheetapp().open_by_url("https://docs.google.com/spreadsheets/d/1tZx9LLvrqkCmvjCxjgBgc-PvaACd7uwpaLev0xMUNQs/edit?usp=sharing")
initial="社会"
r4_l4=pd.read_csv(f"./raw/gsheets/R4コアカリ提出用/{initial}.csv", dtype=str)
r4_l4.fillna("")
sheet.worksheet("第2から4層").update([r4_l4.columns.values.tolist()] + r4_l4.values.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.9/site-packages/requests/models.py:473, in PreparedRequest.prepare_body(self, data, files, json)
#     472 try:
# --> 473     body = complexjson.dumps(json, allow_nan=False)
#     474 except ValueError as ve:
#
# File /opt/conda/lib/python3.9/json/__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# File /opt/conda/lib/python3.9/json/encoder.py:199, in JSONEncoder.encode(self, o)
# ...
